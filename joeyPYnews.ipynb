# %% [markdown]
# <a href="https://colab.research.google.com/github/carzyjoey/CAD104-22-11/blob/main/joeyPYnews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# joey py 抓即時新聞

# %%
pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install requests[socks]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# 實例8 google trend 即時夯話題
import pandas as pd #pandas 0.25
from pytrends.request import TrendReq
pytrend = TrendReq()

# trending_searches_df = pytrend.trending_searches(pn='japan')
trending_searches_df = pytrend.trending_searches(pn='taiwan')
# (pn='south_korea');; (pn='united_states')
print(trending_searches_df.head(20))
# Out:
#           0
# 0   馬丁路德紀念日
# 1       林宜萱
# 2       王嘉爾
# 3       連明月
# 4       螺絲粉
# 5      房貸補貼
# 6     台股封關日
# 7       黃明志
# 8        鴻海
# 9    Jennie
# 10  澳洲網球公開賽
# 11      張穎穎
# 12       假鈔
# 13       和碩
# 14     台鋼雄鷹
# 15     國道四號
# 16      台光電
# 17     甲賀忍蛙
# 18    顎口線蟲病
# 19      富邦金

# %%
# 找出台灣地區，「面膜」一詞的建議關鍵字。
from pytrends.request import TrendReq
import pandas as pd
pytrends = TrendReq(hl='TW',tz=360)
kw_list = '面膜'
pytrends.build_payload(kw_list,cat=0,timeframe='2021-01-01 2021-07-01',geo='TW',gprop='')
keywords = pytrends.suggestions(kw_list)
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')
# Out:
#                          title      type
# 0                  Facial mask     Topic
# 1                       Facial     Topic
# 2                 Facial Scrub     Topic
# 3                   Sheet Mask     Topic
# 4  LANEIGE Water Sleeping Mask  Gel mask

# %%
# 實例6: 針「熱門話題」（例如：疫情,疫苗,基因），一次整理好：話題聲量，話題趨勢，建議使用關鍵字。

# %%
from pytrends.request import TrendReq

# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

kw_list1=['宏佳騰','三輪','三陽','ADIVA'] # jjjjoey

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=kw_list1,timeframe='2022-01-01 2023-01-11',geo='TW') # jjjjoey

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
print("(1)==================================================")
print("interest_over_time_df.tail()：")
print(interest_over_time_df.tail())

# Interest by Region
interest_by_region_df = pytrend.interest_by_region()
print("(2)==================================================")
print("interest_by_region_df.head()：")
print(interest_by_region_df.head())

# Related Queries, returns a dictionary of dataframes
related_queries_dict = pytrend.related_queries()
print("(3)==================================================")
print("related_queries_dict：")
print(related_queries_dict)

# Get Google Hot Trends data
trending_searches_df = pytrend.trending_searches()
print("(4)==================================================")
print("trending_searches_df.head()：")
print(trending_searches_df.head())

# Get Google Hot Trends data
today_searches_df = pytrend.today_searches()
print("(5)==================================================")
print("today_searches_df.head()：")
print(today_searches_df.head())

# Get Google Top Charts
top_charts_df = pytrend.top_charts(2020, hl='en-US', tz=360, geo='TW')
print("(6)==================================================")
print("top_charts_df.head()：")
print(top_charts_df.head())

# Get Google Keyword Suggestions
suggestions_dict = pytrend.suggestions(keyword='Covid-19')
print("(7)==================================================")
print("suggestions_dict：")
print(suggestions_dict)
# Out:
# (1)==================================================
# interest_over_time_df.tail()：
#             宏佳騰  三輪  三陽  ADIVA  isPartial
# date
# 2022-12-11   14  12  67      0      False
# 2022-12-18   15  12  69      1      False
# 2022-12-25   15  11  71      1      False
# 2023-01-01   14  11  78      0      False
# 2023-01-08   14  13  77      2       True
# (2)==================================================
# interest_by_region_df.head()：
#                  宏佳騰  三輪  三陽  ADIVA
# geoName
# Kaohsiung City    19  16  65      0
# New Taipei City   19  12  69      0
# Taichung City     21  13  66      0
# Tainan City       23  12  65      0
# Taipei City       20  14  66      0
# (3)==================================================
# related_queries_dict：
# {'宏佳騰': {'top':            query  value
# 0      宏佳 騰 電動 車    100
# 1           電動 車     99
# 2             機車     49
# 3        宏佳 騰 機車     48
# 4    gogoro 宏佳 騰     29
# 5         gogoro     28
# 6     宏佳 騰 電動機 車     23
# ...

# %%
# 以「自由時報新聞網」為例
import requests
from bs4 import BeautifulSoup

web = requests.get("https://news.ltn.com.tw/")
content = BeautifulSoup( web.text, "html.parser")
allTitle = content.select(".tit .title")
for i in allTitle:
    print("標題："+ i.text )
# Out:
# 標題：挑選寵物年貨有撇步 毛寶貝歡喜過新年
# 標題：發現金案審查衝突不斷 楊瓊瓔批部會連報告都不送
# 標題：蘇格蘭通過法案下修性別轉換門檻 英政府罕見阻擋
# 標題：碗破一小角 命理師揭「捨不得丟」悲慘後果
# 標題：白河景點遊客多 警方春節交管結合科技疏導
# 標題：健保官員涉賣個疑雲 王定宇：馬英九任內共諜滲透最嚴重
# 標題：謠言終結站》演說時「臉擰成一團」 查核中心：拜登也被變臉
# 標題：吃豆花要不要加薑汁？ 賴品妤1張照片意外引起「食物戰爭」
# 標題：小甜甜又失控！當眾氣走小13歲嫩尪 「比中指」嚇壞網友
# 標題：亞洲首展在台灣！Lexus 最新電動概念跑車現身台北展示
# 標題：Jisoo拍男性雜誌尺度大開！鏡頭前「M字開腿」又萌又性感
# 標題：衝浪手「垂足」翹不起來 手術鬆解腓神經 30分鐘解決
# 標題：驚險影像曝光！左轉砂石車急閃前車自撞 差點波及機車與休旅車
# 標題：MiLB》擁有雙重國籍的16歲日本投手 4.2萬美元約加盟馬林魚
# 標題：10天年假天氣狀況曝！吳聖宇：變動頻繁溫度起伏大
# 標題：炎亞綸1句話糾正 王浩宇公開道歉：真的很沒禮貌
# 標題：北韓平壤今召開最高人民會議 金正恩是否出席引關注
# 標題：高中生考數學A忘記簽名丟1級分 提告討成績結果曝
# 標題：健保官員涉賣個資疑雲 李伯璋：系統資料未被存取帶走
# 標題：台股封關前 陸行之列7大半導體產業觀點

# %%
# 以「三立新聞網」為例
import requests
from bs4 import BeautifulSoup
web = requests.get("https://www.setn.com/ViewAll.aspx")
content = BeautifulSoup( web.text, "html.parser" )
allTitle = content.select( ".view-li-title a" )
for i in allTitle:
    print("標題：" + i.text )
# Out:
# 標題：密集恐懼症別看！「長輩的冰箱」衝擊畫面
# 標題：交通部長換人、轉當華航董座？王國材回應
# 標題：2022十大代銷！南北大亂鬥　「海悅」勝出
# 標題：貼門神別犯1禁忌！專家：祂會被鬼當塑膠
# 標題：火鍋店見斑點章魚！專家喊別吃：毒性超強
# 標題：發6000元急又拖　他轟：藍營比皇帝難伺候
# 標題：陸解禁台歌手開唱　網嗨點11組大咖：快來
# 標題：爵士新秀繳20分21籃板！　2014年後第1人
# 標題：少女爽吃麥當勞！抬頭一看米奇深情對望
# 標題：美第一夫人罹皮膚癌！長痣有4症狀危險了
# 標題：與酸民直球對決　周杰倫親回負評不忍了
# 標題：一字萬金！噴漆「欠錢不還」討債反賠5萬
# 標題：刑事局副局長丟官！黃建榮將告女檢王涂芝
# 標題：2024總統大選民調　「他」反而超車侯友宜
# 標題：非敲竹槓！大台北小黃今起加收「這金額」
# 標題：陸軍少將、上校涉騷擾　遭拔官調查
# 標題：中華快遞揚言「年前罷工」！王國材回應了
# 標題：務實台獨成傷害？他：賴清德走蔡英文路線
# 標題：荷爾蒙治療用途廣　性早熟、攝護腺癌均可
# 標題：柯瑞投進6顆三分球轟41分　勇士力退巫師
# 標題：高雄發現金！今天入帳　最高可領1萬500元
# 標題：轟「淫蕩女」揭核彈級內幕　謝和弦突道歉
# 標題：政府發3000元補助　領取方式一次看
# 標題：2023年財運看這篇！這生肖慎防親朋好友
# 標題：拜登私藏機密文件持續延燒　恐衝擊連任
# 標題：力挺白冰冰《初戀》遭酸　男星不忍回應了
# 標題：台光電火燒10小時飄惡臭　環保局將開罰
# 標題：泰坦生涯第5次單場破50分　超越傳奇大鳥
# 標題：學古代美女滾輪瘦臉？醫療技術直接有效
# 標題：苗栗3胞胎兄弟互毆　老大突倒地送醫不治
# 標題：天氣急凍　醫：「單側無力」快去大醫院
# 標題：「統戰」螺螄粉違法！經長：已要求下架
# 標題：新／台中光頭男躲警撞2死！法院裁定收押
# 標題：無慾人妻「春夢太強」驚醒…竟真進來了！
# 標題：內閣即將改組？蘇內閣最新滿意度曝光
# 標題：替王世堅爸爸翻案！學者翻74年前公文揭密
# 標題：《鐘樓怪人》性感女星過世！享耆壽95歲
# 標題：連戰新書重提319槍擊案　陳水扁說話了
# 標題：今年才過15天！科技業每天1600人被裁員
# ...

# %%
# NG   爬蟲修理 -- 以「TVBS新聞」為例
import requests
from bs4 import BeautifulSoup
web = requests.get("https://news.tvbs.com.tw/hot")
content = BeautifulSoup( web.text,"html.parser")
allTitle = content.select(".content_center_contxt_box_news .txt")
for i in allTitle[47:]:
    print("標題：" + i.text )

# %%
pip install GoogleNews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 KB 5.9 MB/s eta 0:00:00
# ...

# %%
from GoogleNews import GoogleNews

googlenews = GoogleNews('en')
# googlenews.search('Trump') # 這裡要改
googlenews.search('ADIVA') # 這裡要改
result = googlenews.result()
print(len(result))

for n in range(len(result)):
    print(n)
    for index in result[n]:
        print(index, '\n', result[n][index])

    exit()
# Out:
# 10
# 0
# title
#  Breeders' Cup Friday Will See 'Magical' Debut
# media
#  BloodHorse
# date
#  Nov 3, 2022
# datetime
#  2022-11-03 00:00:00
# desc
#  Amidst the bustling shedrows and chaos of Breeders' Cup at Keeneland is a filly that, like many others, has yet to make a start.
# link
#  https://www.bloodhorse.com/horse-racing/articles/264548/breeders-cup-friday-will-see-magical-debut
# img
#  ..., Inc. #2 – Saturday, October 22, 2022
# media
#  Canine Chronicle |
# date
#  ct 23, 2022
# datetime
#  None
# desc
#  Show Name: Gloucester County Kennel Club, Inc. Location: Galloway, NJ Show Date: Saturday, October 22, 2022. Total Entry: 475
# link
#  http://caninechronicle.com/show-wins-gallery/gloucester-county-kennel-club-inc-2/
# img
#  ..., 2022
# datetime
#  None
# desc
#  Based on experts' advice, we rounded up the best washable rugs to help you cut down on cleaning time. Two images of a Ruggable rug.
# link
# ...

# %%
# -*- coding: utf-8 -*-
from GoogleNews import GoogleNews

googlenews = GoogleNews('cn')
# googlenews = GoogleNews('tw') #NG 用 cn 就可以找到 台灣新聞
googlenews.search('宏佳騰')
result = googlenews.gettext()
print(len(result))

for n in range(len(result)):
    print(n)
    print(result[n])
# Out:
# 1
# 0
# 宏佳騰三輪摩托車 締造金氏世界紀錄

# %%
# 實例8 google trend 即時夯話題
import pandas as pd #pandas 0.25
from pytrends.request import TrendReq
pytrend = TrendReq()

# trending_searches_df = pytrend.trending_searches(pn='japan')
trending_searches_df = pytrend.trending_searches(pn='taiwan')
# (pn='south_korea');; (pn='united_states')
print(trending_searches_df.head(20))
# Out:
#           0
# 0   馬丁路德紀念日
# 1       林宜萱
# 2       王嘉爾
# 3       連明月
# 4       螺絲粉
# 5      房貸補貼
# 6     台股封關日
# 7       黃明志
# 8        鴻海
# 9    Jennie
# 10  澳洲網球公開賽
# 11      張穎穎
# 12       假鈔
# 13       和碩
# 14     台鋼雄鷹
# 15     國道四號
# 16      台光電
# 17     甲賀忍蛙
# 18    顎口線蟲病
# 19      富邦金
